# %%
from selenium import webdriver as opcoesSelenium
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as tempoEspera


navegador = opcoesSelenium.Chrome()
navegador.get("https://rpachallengeocr.azurewebsites.net/")

tempoEspera.sleep(5)

elementoTabela = navegador.find_element(By.XPATH, '//*[@id="tableSandbox"]')

linhas = elementoTabela.find_elements(By.TAG_NAME,'tr')
colunas = elementoTabela.find_elements(By.TAG_NAME,'td')

linha = 1
for linhaAtual in linhas:
    print(linhaAtual.text)
    linha = linha + 1
# Out:
# The chromedriver version (126.0.6478.127) detected in PATH at c:\Users\bruno.pereira.silva\AppData\Local\anaconda3\chromedriver.exe might not be compatible with the detected chrome version (127.0.6533.100); currently, chromedriver 127.0.6533.119 is recommended for chrome 127.*, so it is advised to delete the driver in PATH and retry
# # ID Due Date Invoice
# 1 rnrzdy4zahjgdv9mczoxrq 07-08-2024
# 2 ctpi9i1pndp1xw09dk0qe 07-09-2024
# 3 z1g21z4fccfiscb9v77d1d 13-09-2024
# 4 vv20lry4u2o3zqtdejh0f 02-07-2024

# %%
from selenium import webdriver as opcoesSelenium
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as tempoEspera

navegador = opcoesSelenium.Chrome()
navegador.get("https://rpachallengeocr.azurewebsites.net/")
tempoEspera.sleep(3)

linha = 1

i = 1

while i < 4:


    elementoTabela = navegador.find_element(By.XPATH, '//*[@id="tableSandbox"]')

    linhas = elementoTabela.find_elements(By.TAG_NAME,'tr')
    colunas = elementoTabela.find_elements(By.TAG_NAME,'td')

    for linhaAtual in linhas:
        print(linhaAtual.text)
        linha = linha + 1

    i += 1

    tempoEspera.sleep(3)
    navegador.find_element(By.XPATH, '//*[@id="tableSandbox_next"]').click()
    tempoEspera.sleep(3)

else:
    print("Pronto!")
# Out:
# The chromedriver version (126.0.6478.127) detected in PATH at c:\Users\bruno.pereira.silva\AppData\Local\anaconda3\chromedriver.exe might not be compatible with the detected chrome version (127.0.6533.100); currently, chromedriver 127.0.6533.119 is recommended for chrome 127.*, so it is advised to delete the driver in PATH and retry
# # ID Due Date Invoice
# 1 0me97t4i90nixzusunkndu 05-09-2024
# 2 5ch2c6ujwsuxd1kr18nww 07-08-2024
# 3 rbj0xybjhotvgc1wx57ol 18-06-2024
# 4 5qsnl9ylmn6gxhg3ug9wia 14-09-2024
# # ID Due Date Invoice
# 5 saj90jqccem3cwulqfi07w 12-10-2024
# 6 3dgtskycfvj4bz3wwu9kv 13-09-2024
# 7 xpxe0c3x4vs3thymahekb 27-06-2024
# 8 1wc2lsjztl6jeh0ub8d84 30-06-2024
# # ID Due Date Invoice
# 9 gx67y1kpb9nnqq98t9znj 07-10-2024
# 10 k80rn7xickqoyh4a5hu0hr 18-09-2024
# 11 btjs9fu4pc4atx9rbxo1f 05-08-2024
# 12 xbir6zucmo41wyu8sqywd 22-07-2024
# Pronto!

# %%
from selenium import webdriver as opcoesSelenium
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as tempoEspera
from openpyxl import load_workbook
import os

nome_arquivo_tabela = "Dados_Tabela.xlsx"
planilhaDadosTabela =  load_workbook(nome_arquivo_tabela)

sheet_selecionad = planilhaDadosTabela['Dados']

navegador = opcoesSelenium.Chrome()
navegador.get("https://rpachallengeocr.azurewebsites.net/")
tempoEspera.sleep(3)

linha = 1

i = 1

while i < 4:

    sheet_dados = planilhaDadosTabela['Dados']

    elementoTabela = navegador.find_element(By.XPATH, '//*[@id="tableSandbox"]')

    linhas = elementoTabela.find_elements(By.TAG_NAME,'tr')
    colunas = elementoTabela.find_elements(By.TAG_NAME,'td')

    for linhaAtual in linhas:        
        
        linha = linha + 1
        linha = len(sheet_dados['A']) + 1
        
        colunaA = "A"+ str(linha)
        colunaB = "B"+ str(linha)
        colunaC = "C"+ str(linha)

        sheet_dados[colunaA] = linhaAtual.text


    i += 1

    tempoEspera.sleep(3)
    navegador.find_element(By.XPATH, '//*[@id="tableSandbox_next"]').click()
    tempoEspera.sleep(3)

else:
    print("Pronto!")

planilhaDadosTabela.save(filename=nome_arquivo_tabela)
os.startfile(nome_arquivo_tabela)
# Out:
# The chromedriver version (126.0.6478.127) detected in PATH at c:\Users\bruno.pereira.silva\AppData\Local\anaconda3\chromedriver.exe might not be compatible with the detected chrome version (127.0.6533.100); currently, chromedriver 127.0.6533.119 is recommended for chrome 127.*, so it is advised to delete the driver in PATH and retry
# Pronto!

# %%
from selenium import webdriver as opcoesSelenium
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as tempoEspera
from openpyxl import load_workbook
import os

nome_arquivo_tabela = "Dados_Tabela.xlsx"
planilhaDadosTabela =  load_workbook(nome_arquivo_tabela)

sheet_selecionad = planilhaDadosTabela['Dados']

navegador = opcoesSelenium.Chrome()
navegador.get("https://rpachallengeocr.azurewebsites.net/")
tempoEspera.sleep(3)

linha = 1

i = 1

while i < 4:

    sheet_dados = planilhaDadosTabela['Dados']

    elementoTabela = navegador.find_element(By.XPATH, '//*[@id="tableSandbox"]')

    linhas = elementoTabela.find_elements(By.TAG_NAME,'tr')
    colunas = elementoTabela.find_elements(By.TAG_NAME,'td')

    for linhaAtual in linhas:        
        
        linha = linha + 1
        linha = len(sheet_dados['A']) + 1
        
        colunaA = "A"+ str(linha)
        colunaB = "B"+ str(linha)
        colunaC = "C"+ str(linha)

        texto = linhaAtual.text
        texto2 = texto.split(" ")

        sheet_dados[colunaA] = texto2[0]
        sheet_dados[colunaB] = texto2[1]
        sheet_dados[colunaC] = texto2[2]


    i += 1

    tempoEspera.sleep(3)
    navegador.find_element(By.XPATH, '//*[@id="tableSandbox_next"]').click()
    tempoEspera.sleep(3)

else:
    print("Pronto!")

planilhaDadosTabela.save(filename=nome_arquivo_tabela)
os.startfile(nome_arquivo_tabela)
# Out:
# The chromedriver version (126.0.6478.127) detected in PATH at c:\Users\bruno.pereira.silva\AppData\Local\anaconda3\chromedriver.exe might not be compatible with the detected chrome version (127.0.6533.100); currently, chromedriver 127.0.6533.119 is recommended for chrome 127.*, so it is advised to delete the driver in PATH and retry
# Pronto!

# %%
from selenium import webdriver as opcoesSelenium
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as tempoEspera


navegador = opcoesSelenium.Chrome()
navegador.get("https://www.mercadolivre.com.br/")

tempoEspera.sleep(5)

navegador.find_element(By.NAME, "as_word").send_keys("carteira")

tempoEspera.sleep(3)

navegador.find_element(By.XPATH, '/html/body/header/div/div[2]/form/button').click()

tempoEspera.sleep(5)

dadosProduto = navegador.find_elements(By.CLASS_NAME, 'ui-search-layout__item')

tempoEspera.sleep(5)

linha = 2
for informacoes in dadosProduto:
    
    nomeProduto = informacoes.find_element(By.CLASS_NAME, 'ui-search-item__title').text
    precoProduto = informacoes.find_element(By.CLASS_NAME, "andes-money-amount__fraction").text
    
    try:
        centavosProduto = informacoes.find_element(By.CLASS_NAME, "andes-money-amount__cents andes-money-amount__cents--superscript-24").text
    except:
        centavosProduto = "00"

    urlProduto = informacoes.find_element(By.TAG_NAME, "a").get_attribute("href")
    

    print(nomeProduto + " - " + precoProduto + "," + centavosProduto + " - "+ urlProduto)
# Out:
# The chromedriver version (126.0.6478.127) detected in PATH at c:\Users\bruno.pereira.silva\AppData\Local\anaconda3\chromedriver.exe might not be compatible with the detected chrome version (127.0.6533.100); currently, chromedriver 127.0.6533.119 is recommended for chrome 127.*, so it is advised to delete the driver in PATH and retry
# Águia Couro Carteira Masculina Com Zíper Carteira Cor Preto\ziper Couro Legitimo - 59,00 - https://click1.mercadolivre.com.br/mclics/clicks/external/MLB/count?a=vjDw01gRNyrDq6S43pXaR4YoK%2BpQpG7tWHJMldQ6CoEj9xSsWJ%2Bl0BB6MQi%2FlmnZ24jpClLNudlK5xqHBpJHhnuvjLaSExz%2BNFvRmqY%2F2yGssxmtOfpgCkhyZkDIeaFwePFHTbFTl7epWvOmDPDGZKwbnS8ly2cbj4gNu5KZTGpHbaN6Cd2EBZl%2B5bfW37npYItwadvDOcO8jkwvCsWqwG%2Bd%2BP%2FN76vfLCuYFQD3lVsNueahslu%2FKo1xjGKPytPzgztSLehUzmUNRh8MxL4rGCzHt6ZsVY5pjgTyQZ5l8P1l296NjqWllLzbcDfgLMB8a7br3oglNaXS%2Fx%2BpKyjN%2BXiGXm%2FQr7rnbx3%2BTCeJW0vgkGTAzks2juLpeGjW2OYZCqO3834Tsyxr17xog0z5mBAgMcNC4V3eav7FioMYQxgj7DwDuL4JS31XhEw3Oat7n7hyHrqylhKLV9q2sTnogyY36TPzbx2JAYsg0eNemkd738SrEL2vziGlPQaszwrpzYyEsMaB1KgFacr06zwpXS2lfR5yWDS%2FINiGxz2JNV16VHLSQrhUqad4VbOb9YsgPaIdp5DMY2zobkfk%2B1LuZvlAswHdYL6JWf%2F3KHxEPtrR1cIQ7D361R%2BIu6dcUQOZnfJ8MhTdNiTnsLLWvo6TSzcqSsAEzusPNXpslcCwbvhtW2r8R0jZgTovgs0TtMmoSnyt7IT51GfbMX7qT6ilOAvNTWl%2BiZN1dOwzVIuk9gZA7laKJgF2csR9%2BJqkVeyVG%2FBLD6ZWXwGW9aPOntkKekfQSZ7G4O%2FR1r54TEDsKLnXWjHmmwYUFh0kS0NZoUy2CNX%2BMqzfArHCeS0gb6KP&e=mclics%2Fadvertising-results-augmenter-on%2B15098%2Cmclics%2Fvariant-candidates%2B31710%2Cmclics%2Fpseudo-search-pads-buybox%2B7708%2Cmclics%2Fdiscard-bid-lt-min%2B45362%2Cmclics%2Fmax-bid-capped%2B36382%2Cmclics%2Fmax-bid-item-factor%2B23927%2Cmclics%2Foverride-min-seasonality%2B49092&rb=x
# Carteira Masculina Couro legitimo Vastigriff 2140 preto - 94,00 - https://click1.mercadolivre.com.br/mclics/clicks/external/MLB/count?a
26search_layout%3Dgrid%26type%3Ditem%26tracking_id%3D622d37b6-8aae-4f0c-a787-b434c9b8881e
# Carteira Mágica Porta Cartão Couro Legítimo Cnh Cédulas - 29,00 - https://produto.mercadolivre.com.br/MLB-1927245212-carteira-magica-porta-carto-couro-legitimo-cnh-cedulas-_JM?searchVariation=88982729295#position%3D54%26search_layout%3Dgrid%26type%3Ditem%26tracking_id%3D622d37b6-8aae-4f0c-a787-b434c9b8881e
# Maktub Carteira Magica Masculina Azul Para Cartao Cnh - 39,00 - https://www.mercadolivre.com.br/maktub-carteira-magica-masculina-azul-para-cartao-cnh/p/MLB22806030#searchVariation%3DMLB22806030%26position%3D37%26search_layout%3Dgrid%26type%3Dproduct%26tracking_id%3D622d37b6-8aae-4f0c-a787-b434c9b8881e
# BellVOLPE Carteira Mini 10.7x7.2cm preto e marinho - 78,00 - https://www.mercadolivre.com.br/bellvolpe-carteira-mini-107x72cm-preto-e-marinho/p/MLB37987903#searchVariation%3DMLB37987903%26position%3D38%26search_layout%3Dgrid%26type%3Dproduct%26tracking_id%3D622d37b6-8aae-4f0c-a787-b434c9b8881e

# %%
from selenium import webdriver as opcoesSelenium
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyautogui as tempoEspera
from openpyxl import load_workbook
import os

nome_arquivo_tabela = "Dados_Tabela.xlsx"
planilhaDadosTabela =  load_workbook(nome_arquivo_tabela)

sheet_dados = planilhaDadosTabela['Dados']


navegador = opcoesSelenium.Chrome()
navegador.get("https://www.mercadolivre.com.br/")

tempoEspera.sleep(5)

navegador.find_element(By.NAME, "as_word").send_keys("carteira")

tempoEspera.sleep(3)

navegador.find_element(By.XPATH, '/html/body/header/div/div[2]/form/button').click()

tempoEspera.sleep(5)

dadosProduto = navegador.find_elements(By.CLASS_NAME, 'ui-search-layout__item')

tempoEspera.sleep(5)

linha = 2
for informacoes in dadosProduto:    
    
    nomeProduto = informacoes.find_element(By.CLASS_NAME, 'ui-search-item__title').text
    precoProduto = informacoes.find_element(By.CLASS_NAME, "andes-money-amount__fraction").text
    
    try:
        centavosProduto = informacoes.find_element(By.CLASS_NAME, 'andes-money-amount__cents').text
    except:
        centavosProduto = "00"

    urlProduto = informacoes.find_element(By.TAG_NAME, "a").get_attribute("href")

    linha = len(sheet_dados['A']) + 1
        
    colunaA = "A"+ str(linha)
    colunaB = "B"+ str(linha)
    colunaC = "C"+ str(linha)

    sheet_dados["A1"] = "Produto"    
    sheet_dados["B1"] = "Preço"    
    sheet_dados["C1"] = "Imagem"

    precoTexto = precoProduto+","+centavosProduto
    precoSemPonto = precoTexto.replace('.','')
    precoSemPonto2 = precoTexto.replace(',','.')
    precoSemPonto2 = float(precoSemPonto2)

    sheet_dados[colunaA] = nomeProduto
    sheet_dados[colunaB] = precoSemPonto2
    sheet_dados[colunaC] = urlProduto

    
planilhaDadosTabela.save(filename=nome_arquivo_tabela)
os.startfile(nome_arquivo_tabela)
# Out:
# The chromedriver version (126.0.6478.127) detected in PATH at c:\Users\bruno.pereira.silva\AppData\Local\anaconda3\chromedriver.exe might not be compatible with the detected chrome version (127.0.6533.100); currently, chromedriver 127.0.6533.119 is recommended for chrome 127.*, so it is advised to delete the driver in PATH and retry
