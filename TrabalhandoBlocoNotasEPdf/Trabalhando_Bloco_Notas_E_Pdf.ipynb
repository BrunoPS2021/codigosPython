# %%
arquivo = open('Alunos.txt')
linhas = arquivo.readlines()

print(linhas)
# Out:
# ['Escola;Professora;ID;Aluno;Nota 1;Nota 2;Nota 3;Nota 4;Faltas\n', 'ABC;Rosiane;782707;Aline Rosa;5;10;7;7;2\n', 'Filho;Carolina;437686;Amanda Martins;6;10;10;9;3\n', 'ABC;Rosiane;310916;Angela Maria;8;10;7;10;5\n', 'ABC;Carolina;760926;Carlos Moreira;10;4;7;6;2\n', 'Filho;Rosiane;557848;Eliane Moreira;10;6;5;4;3\n', 'ABC;Rosiane;758465;Leonardo Almeida;8;9;6;9;2\n', 'ABC;Carolina;235215;Nicolas Pereira;1;2;2;2;3\n', 'ABC;Rosiane;751595;Paulo Santos;9;7;10;9;0\n', 'ABC;Carolina;760936;Raul Silva;8;10;5;10;4\n', 'Filho;Rosiane;557858;Reinaldo Assis;8;8;8;5;5\n', 'ABC;Carolina;758475;Eduardo Pires;8;9;8;9;1\n']

# %%
arquivo = open('Alunos.txt')
arquivoBlocoDeNotas = arquivo.readlines()

for linha in arquivoBlocoDeNotas:
    quebraLinha = linha.split(',')

    #print(quebraLinha)

    linha = [item.split(';', 1)[1] for item in quebraLinha]

    separaLinhaEmColuna = linha[0].split(';')

    nome = separaLinhaEmColuna[2]

    print(nome)
# Out:
# Aluno
# Aline Rosa
# Amanda Martins
# Angela Maria
# Carlos Moreira
# Eliane Moreira
# Leonardo Almeida
# Nicolas Pereira
# Paulo Santos
# Raul Silva
# Reinaldo Assis
# Eduardo Pires

# %%
arquivo = open('Alunos.txt')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

for linha in arquivoBlocoDeNotas:
    quebraLinha = linha.split(',')

    #print(quebraLinha)

    linha = [item.split(';', 1)[1] for item in quebraLinha]

    separaLinhaEmColuna = linha[0].split(';')

    nome = separaLinhaEmColuna[2]
    
    if separaLinhaEmColuna[3] == "Nota 1":
        print("--------Título----------")
    else:
        print(nome)

        nota1 = int(separaLinhaEmColuna[3])
        nota2 = int(separaLinhaEmColuna[4])
        nota3 = int(separaLinhaEmColuna[5])
        nota4 = int(separaLinhaEmColuna[6])
        faltas = int(separaLinhaEmColuna[7])

        print("Nota1: ",nota1)
        print("Nota2: ",nota2)
        print("Nota3: ",nota3)
        print("Nota4: ",nota4)
        print("Faltas: ",faltas)

        media = (nota1 + nota2 + nota3 + nota4) / 4

        print("Média: ", media)

        if faltas >= 4:
            print("Aluno(a) reprovado(a) por faltas")
        else:
            if media >= 6:
                print("Aluno(a) aprovado(a)")
            elif media >= 4:
                print("Aluno(a) esta em recuperação")
            else:
                print("Aluno(a) reprovado(a) por media")

        print("-------------------------------------")
# Out:
# --------Título----------
# Aline Rosa
# Nota1:  5
# Nota2:  10
# Nota3:  7
# Nota4:  7
# Faltas:  2
# Média:  7.25
# Aluno(a) aprovado(a)
# -------------------------------------
# Amanda Martins
# Nota1:  6
# Nota2:  10
# Nota3:  10
# Nota4:  9
# Faltas:  3
# Média:  8.75
# Aluno(a) aprovado(a)
# -------------------------------------
# Angela Maria
# Nota1:  8
# Nota2:  10
# Nota3:  7
# Nota4:  10
# Faltas:  5
# Média:  8.75
# Aluno(a) reprovado(a) por faltas
# -------------------------------------
# Carlos Moreira
# Nota1:  10
# Nota2:  4
# Nota3:  7
# Nota4:  6
# Faltas:  2
# Média:  6.75
# Aluno(a) aprovado(a)
# -------------------------------------
# Eliane Moreira
# Nota1:  10
# Nota2:  6
# Nota3:  5
# Nota4:  4
# Faltas:  3
# Média:  6.25
# Aluno(a) aprovado(a)
# -------------------------------------
# Leonardo Almeida
# Nota1:  8
# Nota2:  9
# Nota3:  6
# Nota4:  9
# Faltas:  2
# Média:  8.0
# Aluno(a) aprovado(a)
# -------------------------------------
# Nicolas Pereira
# ...

# %%
arquivo = open('Alunos.txt')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

for linha in arquivoBlocoDeNotas:
    quebraLinha = linha.split(',')

    #print(quebraLinha)

    linha = [item.split(';', 1)[1] for item in quebraLinha]

    separaLinhaEmColuna = linha[0].split(';')

    professora = separaLinhaEmColuna[0]

    if professora == "Carolina":

        print("Professora: ", professora)

        nome = separaLinhaEmColuna[2]
        
        if separaLinhaEmColuna[3] == "Nota 1":
            print("--------Título----------")
        else:
            print(nome)

            nota1 = int(separaLinhaEmColuna[3])
            nota2 = int(separaLinhaEmColuna[4])
            nota3 = int(separaLinhaEmColuna[5])
            nota4 = int(separaLinhaEmColuna[6])
            faltas = int(separaLinhaEmColuna[7])

            print("Nota1: ",nota1)
            print("Nota2: ",nota2)
            print("Nota3: ",nota3)
            print("Nota4: ",nota4)
            print("Faltas: ",faltas)

            media = (nota1 + nota2 + nota3 + nota4) / 4

            print("Média: ", media)

            if faltas >= 4:
                print("Aluno(a) reprovado(a) por faltas")
            else:
                if media >= 6:
                    print("Aluno(a) aprovado(a)")
                elif media >= 4:
                    print("Aluno(a) esta em recuperação")
                else:
                    print("Aluno(a) reprovado(a) por media")

            print("-------------------------------------")
# Out:
# Professora:  Carolina
# Amanda Martins
# Nota1:  6
# Nota2:  10
# Nota3:  10
# Nota4:  9
# Faltas:  3
# Média:  8.75
# Aluno(a) aprovado(a)
# -------------------------------------
# Professora:  Carolina
# Carlos Moreira
# Nota1:  10
# Nota2:  4
# Nota3:  7
# Nota4:  6
# Faltas:  2
# Média:  6.75
# Aluno(a) aprovado(a)
# -------------------------------------
# Professora:  Carolina
# Nicolas Pereira
# Nota1:  1
# Nota2:  2
# Nota3:  2
# Nota4:  2
# Faltas:  3
# Média:  1.75
# Aluno(a) reprovado(a) por media
# -------------------------------------
# Professora:  Carolina
# Raul Silva
# Nota1:  8
# Nota2:  10
# Nota3:  5
# Nota4:  10
# Faltas:  4
# Média:  8.25
# Aluno(a) reprovado(a) por faltas
# -------------------------------------
# Professora:  Carolina
# Eduardo Pires
# Nota1:  8
# Nota2:  9
# Nota3:  8
# Nota4:  9
# Faltas:  1
# Média:  8.5
# Aluno(a) aprovado(a)
# -------------------------------------

# %%
arquivoProfessoraCarolina = open('ProfessoraCarolina.txt', 'w')
arquivo = open('Alunos.txt','r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

for linha in arquivoBlocoDeNotas:
    quebraLinha = linha.split(',')

    #print(quebraLinha)

    linha = [item.split(';', 1)[1] for item in quebraLinha]

    separaLinhaEmColuna = linha[0].split(';')

    professora = separaLinhaEmColuna[0]

    if professora == "Carolina":

        
        nome = separaLinhaEmColuna[2]
        
        if separaLinhaEmColuna[3] == "Nota 1":
            print("------------------")
        else:
            
            nota1 = int(separaLinhaEmColuna[3])
            nota2 = int(separaLinhaEmColuna[4])
            nota3 = int(separaLinhaEmColuna[5])
            nota4 = int(separaLinhaEmColuna[6])
            faltas = int(separaLinhaEmColuna[7])
            
            media = (nota1 + nota2 + nota3 + nota4) / 4

            if faltas >= 4:
                arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) reprovado(a) por faltas\n')
            else:
                if media >= 6:
                    arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) aprovado(a)\n')
                elif media >= 4:
                    arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) esta em recuperação\n')
                else:
                    arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) reprovado(a) por media\n')

# %%
arquivoProfessoraCarolina = open('ProfessoraCarolina.txt', 'w')
arquivoProfessoraRosiane = open('ProfessoraRosiane.txt', 'w')
arquivo = open('Alunos.txt','r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

for linha in arquivoBlocoDeNotas:
    quebraLinha = linha.split(',')

    #print(quebraLinha)

    linha = [item.split(';', 1)[1] for item in quebraLinha]

    separaLinhaEmColuna = linha[0].split(';')

    professora = separaLinhaEmColuna[0]

    if professora == "Carolina":
        
        nome = separaLinhaEmColuna[2]
        
        if separaLinhaEmColuna[3] == "Nota 1":
            print("------------------")
        else:
            
            nota1 = int(separaLinhaEmColuna[3])
            nota2 = int(separaLinhaEmColuna[4])
            nota3 = int(separaLinhaEmColuna[5])
            nota4 = int(separaLinhaEmColuna[6])
            faltas = int(separaLinhaEmColuna[7])
            
            media = (nota1 + nota2 + nota3 + nota4) / 4

            if faltas >= 4:
                arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) reprovado(a) por faltas\n')
            else:
                if media >= 6:
                    arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) aprovado(a)\n')
                elif media >= 4:
                    arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) esta em recuperação\n')
                else:
                    arquivoProfessoraCarolina.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) reprovado(a) por media\n')
            
    
    if professora == "Rosiane":
        
        nome = separaLinhaEmColuna[2]
        
        if separaLinhaEmColuna[3] == "Nota 1":
            print("------------------")
        else:
            
            nota1 = int(separaLinhaEmColuna[3])
            nota2 = int(separaLinhaEmColuna[4])
            nota3 = int(separaLinhaEmColuna[5])
            nota4 = int(separaLinhaEmColuna[6])
            faltas = int(separaLinhaEmColuna[7])
            
            media = (nota1 + nota2 + nota3 + nota4) / 4

            if faltas >= 4:
                arquivoProfessoraRosiane.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) reprovado(a) por faltas\n')
            else:
                if media >= 6:
                    arquivoProfessoraRosiane.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) aprovado(a)\n')
                elif media >= 4:
                    arquivoProfessoraRosiane.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) esta em recuperação\n')
                else:
                    arquivoProfessoraRosiane.write(nome + ', Média: '+ str(media) + ', Faltas: '+ str(faltas)+ ' - Aluno(a) reprovado(a) por media\n')

# %%
# !pip install fpdf
# Out:
# ...
#   Using cached fpdf-1.7.2-py2.py3-none-any.whl
# ...

# %%
from fpdf import FPDF

pdf = FPDF()

pdf.add_page()

pdf.set_font("Arial", size= 12)

arquivo = open('ProfessoraRosiane.txt', 'r')

w = 0

h = 0

for linha in arquivo:
    pdf.cell(w,h=10,txt = linha, border=1,ln=1,
             align='L', fill=False, link='https://www.google.com/')
    
pdf.output('ProfessoraRosiane.pdf')
# Out:
# ''

# %%
from fpdf import FPDF

pdf = FPDF()

pdf.add_page()

pdf.set_font("Arial", size= 15)
pdf.cell(200, 10, txt = "Escola ABC", ln=1, align='C')
pdf.cell(200, 10, txt = "Turma 5 / 2024", ln=1, align='C')
pdf.cell(200, 10, txt = "", ln=1, align='C')

pdf.set_font("Arial", size= 12)
arquivo = open('ProfessoraRosiane.txt', 'r')

w = 0
h = 0

for linha in arquivo:
    pdf.cell(w,h=10,txt = linha, border=1,ln=1,
             align='L', fill=False, link='https://www.google.com/')
    
pdf.output('PDF Professora Rosiane.pdf')

print("PDF criado com sucesso!")
# Out:
# PDF criado com sucesso!

# %%
# !pip install pandas

# %%
import pandas as pd

arquivoProfessoraCarolina = open('ProfessoraCarolina.txt', 'w')
arquivo = open('Alunos.txt','r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

arquivoProfessoraCarolina.write('ID;Aluno;Média;Faltas;Situação\n')

for linha in arquivoBlocoDeNotas:
    quebraLinha = linha.split(',')

    #print(quebraLinha)

    linha = [item.split(';', 1)[1] for item in quebraLinha]

    separaLinhaEmColuna = linha[0].split(';')

    professora = separaLinhaEmColuna[0]

    if professora == "Carolina":

        
        nome = separaLinhaEmColuna[2]
        
        if separaLinhaEmColuna[3] == "Nota 1":
            print("------------------")
        else:
            
            nota1 = int(separaLinhaEmColuna[3])
            nota2 = int(separaLinhaEmColuna[4])
            nota3 = int(separaLinhaEmColuna[5])
            nota4 = int(separaLinhaEmColuna[6])
            faltas = int(separaLinhaEmColuna[7])
            
            media = (nota1 + nota2 + nota3 + nota4) / 4

            if faltas >= 4:
                arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) reprovado(a) por faltas\n')
            else:
                if media >= 6:
                    arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) aprovado(a)\n')
                elif media >= 4:
                    arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) esta em recuperação\n')
                else:
                    arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) reprovado(a) por media\n')

arquivoProfessoraCarolina.close()

#enconding = 'cp1252'
#enconding = 'ISO-8859-1'

configuracaoIdioma = 'utf-8-sig'            
arquivoDataFrame = pd.read_csv('ProfessoraCarolina.txt',encoding=configuracaoIdioma)

arquivoDataFrame.to_csv('ProfessoraCarolina.csv',encoding='utf-8-sig')

# %%
import pandas as pd

arquivoProfessoraCarolina = open('ProfessoraCarolina.txt', 'w')
arquivoProfessoraRosiane = open('ProfessoraRosiane.txt', 'w')
arquivo = open('Alunos.txt','r')
arquivoBlocoDeNotas = arquivo.readlines()

nota1 = 0
nota2 = 0
nota3 = 0
nota4 = 0
faltas = 0

arquivoProfessoraCarolina.write('ID;Aluno;Média;Faltas;Situação\n')
arquivoProfessoraRosiane.write('ID;Aluno;Média;Faltas;Situação\n')


for linha in arquivoBlocoDeNotas:
    quebraLinha = linha.split(',')

    #print(quebraLinha)

    linha = [item.split(';', 1)[1] for item in quebraLinha]

    separaLinhaEmColuna = linha[0].split(';')

    professora = separaLinhaEmColuna[0]

    if professora == "Carolina":

        
        nome = separaLinhaEmColuna[2]
        
        if separaLinhaEmColuna[3] == "Nota 1":
            print("------------------")
        else:
            
            nota1 = int(separaLinhaEmColuna[3])
            nota2 = int(separaLinhaEmColuna[4])
            nota3 = int(separaLinhaEmColuna[5])
            nota4 = int(separaLinhaEmColuna[6])
            faltas = int(separaLinhaEmColuna[7])
            
            media = (nota1 + nota2 + nota3 + nota4) / 4

            if faltas >= 4:
                arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) reprovado(a) por faltas\n')
            else:
                if media >= 6:
                    arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) aprovado(a)\n')
                elif media >= 4:
                    arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) esta em recuperação\n')
                else:
                    arquivoProfessoraCarolina.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) reprovado(a) por media\n')

    elif professora == "Rosiane":

        
        nome = separaLinhaEmColuna[2]
        
        if separaLinhaEmColuna[3] == "Nota 1":
            print("------------------")
        else:
            
            nota1 = int(separaLinhaEmColuna[3])
            nota2 = int(separaLinhaEmColuna[4])
            nota3 = int(separaLinhaEmColuna[5])
            nota4 = int(separaLinhaEmColuna[6])
            faltas = int(separaLinhaEmColuna[7])
            
            media = (nota1 + nota2 + nota3 + nota4) / 4

            if faltas >= 4:
                arquivoProfessoraRosiane.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) reprovado(a) por faltas\n')
            else:
                if media >= 6:
                    arquivoProfessoraRosiane.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) aprovado(a)\n')
                elif media >= 4:
                    arquivoProfessoraRosiane.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) esta em recuperação\n')
                else:
                    arquivoProfessoraRosiane.write(';'+nome + '; Média: '+ str(media) + '; Faltas: '+ str(faltas)+ '; Aluno(a) reprovado(a) por media\n')


arquivoProfessoraCarolina.close()
arquivoProfessoraRosiane.close()

#enconding = 'cp1252'
#enconding = 'ISO-8859-1'

configuracaoIdioma = 'utf-8-sig'            

arquivoDataFrame = pd.read_csv('ProfessoraCarolina.txt',encoding=configuracaoIdioma)
arquivoDataFrame.to_csv('ProfessoraCarolina.csv',encoding=configuracaoIdioma)


arquivoDataFrame2 = pd.read_csv('ProfessoraRosiane.txt',encoding=configuracaoIdioma)
arquivoDataFrame2.to_csv('ProfessoraRosiane.csv',encoding=configuracaoIdioma)

# %%
import pandas as opcoesPandas
import os

caminhoArquivos = 'arquivos'

listaArquivos = os.listdir(caminhoArquivos)

print(listaArquivos)

listaCaminhoEArquivoBlocoNotas = [caminhoArquivos + '\\' + arquivo for arquivo in listaArquivos if arquivo[-3:] == 'txt']

print(listaCaminhoEArquivoBlocoNotas)

dadosArquivos = opcoesPandas.DataFrame()

for arquivo in listaCaminhoEArquivoBlocoNotas:
    dados = opcoesPandas.read_csv(arquivo)
    dadosArquivos = opcoesPandas.concat([dadosArquivos, dados])

dadosArquivos.to_csv('Arquivo Consolidado.csv',index=False)
# Out:
# ['Arquivo1.txt', 'Arquivo2.txt', 'Arquivo3.txt', 'Arquivo4.txt', 'Arquivo5.txt']
# ['arquivos\\Arquivo1.txt', 'arquivos\\Arquivo2.txt', 'arquivos\\Arquivo3.txt', 'arquivos\\Arquivo4.txt', 'arquivos\\Arquivo5.txt']

# %%
import PyPDF2 as opcoesPDF

opcoesPDF.PdfFileReader

opcoesPDF.PdfFileWriter

opcoesPDF.PdfFileMerger

from PyPDF2 import PdfReader

caminhoArquivo = 'Mercado_livre.pdf'

arquivo_Mercado_Livre = PdfReader(caminhoArquivo)

numeroPaginas = len(arquivo_Mercado_Livre.pages)

print(f"{numeroPaginas} páginas")

try:
    informacoes = arquivo_Mercado_Livre.metadata

    print(informacoes)
except AttributeError:
    print('Não foi possível acessar as informações do documento.')
# Out:
# 71 páginas
# {'/Title': 'Mercado Livre #oMelhorTáChegando', '/Author': 'Felipe Nunes Garcia', '/Keywords': 'Internal', '/CreationDate': "D:20200728114956-03'00'", '/ModDate': "D:20200728114956-03'00'", '/Producer': 'Microsoft® PowerPoint® para Office 365', '/Creator': 'Microsoft® PowerPoint® para Office 365'}

# %%
from PyPDF2 import PdfReader

arquivoPDF = PdfReader("Evolução_Amazon.pdf")

contaNumeroPaginas = len(arquivoPDF.pages)

print(contaNumeroPaginas)

pagina = arquivoPDF.pages[0]

textoPagina1 = pagina.extract_text()

print(textoPagina1)
# Out:
# 8
# Como Evoluiu o Modelo de Negócio da Amazon ?
# HISTÓRICO E SUA CORRELAÇÃO COM OS RESULTADOS DA EMPRESA
# 0Outubro de 2016.ESTUDO DESENVOLVIDO PELA LUNICA CONSULTORIA,
# ESPECIALIZADA EM ESTRATÉGIA DE NEGÓCIO.

# %%
from PyPDF2 import PdfReader
import datetime

try:
    arquivoPDF = PdfReader("Mercado_Livre.pdf")
    dados = arquivoPDF.metadata
    num_paginas = len(arquivoPDF.pages)

    print("Autor:",dados.author if dados.author else "Não disponível")
    print("Criador:",dados.creator if dados.creator else "Não disponível")
    print("Produtor:",dados.producer if dados.producer else "Não disponível")
    print("Assunto:",dados.subject if dados.subject else "Não disponível")
    print("Título:",dados.title if dados.title else "Não disponível")
    print(f"Número total de páginas: {num_paginas}")
    print("Documento Criptografado:","Sim" if arquivoPDF.is_encrypted else "Não")
    
    data_criacao = dados.get("/CreationDate","Não disponível")
    data_modificacao = dados.get("/ModDate", "Não disponível")

    if data_criacao != "Não disponível":
        data_criacao = datetime.datetime.strptime(data_criacao[2:-7], '%Y%m%d%H%M%S')
        print("Data de Criação:", data_criacao)
    else:
        print("Data de Criação: Não disponível")

    if data_modificacao != "Não disponível":
        data_modificacao = datetime.datetime.strptime(data_modificacao[2:-7], '%Y%m%d%H%M%S')
        print("Data de Modificação:", data_modificacao)
    else:
        print("Data de Modificação: Não disponível")

except FileNotFoundError:
    print("Arquivo PDF de origem não encontrado. Verifique o caminho do arquivo")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Autor: Felipe Nunes Garcia
# Criador: Microsoft® PowerPoint® para Office 365
# Produtor: Microsoft® PowerPoint® para Office 365
# Assunto: Não disponível
# Título: Mercado Livre #oMelhorTáChegando
# Número total de páginas: 71
# Documento Criptografado: Não
# Data de Criação: 2020-07-28 11:49:56
# Data de Modificação: 2020-07-28 11:49:56

# %%
from PyPDF2 import PdfReader, PdfWriter
import os

try:
    arquivoPDF = PdfReader("Mercado_Livre.pdf")
    novoArquivoPDF = PdfWriter()

    for pagina in arquivoPDF.pages:
        novoArquivoPDF.add_page(pagina)

    novoArquivoPDF.add_metadata(
        {
            "/Author": "Bruno Pereira da Silva",
            "/Creator": "Python PdfWriter",
            "/Producer": "Curso de Python PDF",
            "/Subject": "Ensinando a trabalhar com PDF",
            "/Title": "Curso RPA Python",
        }
    )

    novo_arquivo = 'Arquivo_Alterado_Mercado_Livre.pdf'

    with open(novo_arquivo, "wb") as dadosArquivo:
        novoArquivoPDF.write(dadosArquivo)

    if os.path.exists(novo_arquivo):
        print(f"Arquivo '{novo_arquivo}' criado com sucesso!")
    else:
        print(f"Erro ao criar o arquivo '{novo_arquivo}'")

except FileNotFoundError:
    print("Arquivo PDF de origem não encontrado. Verifique o caminho do arquivo")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Arquivo 'Arquivo_Alterado_Mercado_Livre.pdf' criado com sucesso!

# %%
from PyPDF2 import PdfReader
import datetime

try:
    arquivoPDF = PdfReader("Arquivo_Alterado_Mercado_Livre.pdf")
    dados = arquivoPDF.metadata
    num_paginas = len(arquivoPDF.pages)

    print("Autor:",dados.author if dados.author else "Não disponível")
    print("Criador:",dados.creator if dados.creator else "Não disponível")
    print("Produtor:",dados.producer if dados.producer else "Não disponível")
    print("Assunto:",dados.subject if dados.subject else "Não disponível")
    print("Título:",dados.title if dados.title else "Não disponível")
    print(f"Número total de páginas: {num_paginas}")
    print("Documento Criptografado:","Sim" if arquivoPDF.is_encrypted else "Não")
    
    data_criacao = dados.get("/CreationDate","Não disponível")
    data_modificacao = dados.get("/ModDate", "Não disponível")

    if data_criacao != "Não disponível":
        data_criacao = datetime.datetime.strptime(data_criacao[2:-7], '%Y%m%d%H%M%S')
        print("Data de Criação:", data_criacao)
    else:
        print("Data de Criação: Não disponível")

    if data_modificacao != "Não disponível":
        data_modificacao = datetime.datetime.strptime(data_modificacao[2:-7], '%Y%m%d%H%M%S')
        print("Data de Modificação:", data_modificacao)
    else:
        print("Data de Modificação: Não disponível")

except FileNotFoundError:
    print("Arquivo PDF de origem não encontrado. Verifique o caminho do arquivo")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Autor: Bruno Pereira da Silva
# Criador: Python PdfWriter
# Produtor: Curso de Python PDF
# Assunto: Ensinando a trabalhar com PDF
# Título: Curso RPA Python
# Número total de páginas: 71
# Documento Criptografado: Não
# Data de Criação: Não disponível
# Data de Modificação: Não disponível

# %%
from PyPDF2 import PdfReader, PdfWriter

try:
    arquivoPDF = PdfReader("Arquivo_Alterado_Mercado_Livre.pdf")
    novoArquivoPDF = PdfWriter()

    for pagina in arquivoPDF.pages:
        novoArquivoPDF.add_page(pagina)

    novoArquivoPDF.encrypt("aluno")

    novo_arquivo_com_senha = "Senha_Arquivo_Alterado_Mercado_Livre.pdf"

    with open(novo_arquivo_com_senha, "wb") as dadosArquivo:
        novoArquivoPDF.write(dadosArquivo)

    print("Arquivo PDF protegido por senha criado com sucesso!")

except FileNotFoundError:
    print("Arquivo PDF de origem não encontrado. Verifique o caminho do arquivo")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Arquivo PDF protegido por senha criado com sucesso!

# %%
from PyPDF2 import PdfReader, PdfWriter

try:
    arquivoPDF = PdfReader("Senha_Arquivo_Alterado_Mercado_Livre.pdf")

    novoArquivoPDF = PdfWriter()

    if arquivoPDF.is_encrypted:
        arquivoPDF.decrypt('aluno')

    for pagina in arquivoPDF.pages:
        novoArquivoPDF.add_page(pagina)

    novo_arquivo_sem_senha = "Desprotegido_Arquivo_alterado_Mercado_Livre.pdf"

    with open(novo_arquivo_sem_senha, "wb") as dadosArquivo:
        novoArquivoPDF.write(dadosArquivo)

    print("Arquivo PDF desprotegido por senha criado com sucesso!")

except FileNotFoundError:
    print("Arquivo PDF de origem não encontrado. Verifique o caminho do arquivo")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Arquivo PDF desprotegido por senha criado com sucesso!

# %%
from PyPDF2 import PdfReader, PdfWriter
from pathlib import Path

caminhoArquivo = "Mercado_Livre.pdf"

PDF_MercadoLivre = PdfReader(caminhoArquivo)

numeroPagina = 1

for pagina in PDF_MercadoLivre.pages:
    novoPDF = PdfWriter()
    novoPDF.add_page(pagina)
    
    caminhoPasta = "PDFS Mercado Livre\\"

    Path(caminhoPasta).mkdir(parents=True, exist_ok=True)

    caminhoArquivoNovo = Path(caminhoPasta + 'Aruivo_Mercado_Livre'+ str(numeroPagina) + '.pdf')

    with caminhoArquivoNovo.open(mode='wb') as arquivoConcluido:
        novoPDF.write(arquivoConcluido)

    numeroPagina += 1

print("Concluido!")
# Out:
# Concluido!

# %%
from PyPDF2 import PdfReader, PdfWriter
from pathlib import Path

caminhoArquivo = "Mercado_Livre.pdf"

try:
    PDF_MercadoLivre = PdfReader(caminhoArquivo)
    numeroPagina = 1

    for pagina in PDF_MercadoLivre.pages:
        pagina.rotate(270)
        
        novoPDF = PdfWriter()
        novoPDF.add_page(pagina)

        caminhoPasta = "PDFs Mercado Livre Rotacionado\\"

        Path(caminhoPasta).mkdir(parents=True,exist_ok=True)

        caminhoArquivoNovo = Path(caminhoPasta + "Arquivo_Mercado_Livre"+ str(numeroPagina)+ ".pdf")
        
        with caminhoArquivoNovo.open(mode='wb') as arquivoConcluido:
            novoPDF.write(arquivoConcluido)

        numeroPagina += 1

    print('Arquivo PDF com páginas rotacionadas criado com sucesso!')

except FileNotFoundError:
    print("Arquivo PDF de origem não encontrado. Verifique o caminho do arquivo")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Arquivo PDF com páginas rotacionadas criado com sucesso!

# %%
from PyPDF2 import PdfReader, PdfWriter
from pathlib import Path

caminhoArquivo = "Mercado_Livre.pdf"

try:
    PDF_MercadoLivre = PdfReader(caminhoArquivo)
    paginas = [5, 10, 15, 20]

    novoPDF = PdfWriter()

    for i, pagina in enumerate(PDF_MercadoLivre.pages, start=1):
        if i in paginas:
            novoPDF.add_page(pagina)
            print(f"Adicionando página {i}")

    caminhoPasta = "PDFs Páginas Especificas Mercado Livre\\"
    Path(caminhoPasta).mkdir(parents=True,exist_ok=True)
    
    caminhoArquivoNovo = Path(caminhoPasta + 'Arquivo_Mercado_Livre.pdf')

    with caminhoArquivoNovo.open(mode='wb') as arquivoConcluido:
        novoPDF.write(arquivoConcluido)

    print("Arquivo PDF com páginas selecionadas criado com sucesso!")
    
except FileNotFoundError:
    print("Arquivo PDF de origem não encontrado. Verifique o caminho do arquivo")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Adicionando página 5
# Adicionando página 10
# Adicionando página 15
# Adicionando página 20
# Arquivo PDF com páginas selecionadas criado com sucesso!

# %%
from PyPDF2 import PdfMerger
from pathlib import Path

try:
    pdf_Principal = PdfMerger()

    pdf1 = "Evolução_Amazon.pdf"
    pdf2 = "Mercado_Livre.pdf"

    pdf_Principal.append(pdf1)
    pdf_Principal.append(pdf2)

    caminhoPasta = "PDFs Juntos\\"
    Path(caminhoPasta).mkdir(parents=True,exist_ok=True)
    caminhoArquivoMesclado = Path(caminhoPasta + 'PDF_Consolidado.pdf')

    with caminhoArquivoMesclado.open(mode='wb') as arquivoConcluido:
        pdf_Principal.write(arquivoConcluido)

    print("Arquivo PDF mesclado criado com sucesso!")

except FileNotFoundError:
    print(" Um dos arquivos PDF de origem não encontrado. Verifique o caminho dos arquivos")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Aruivo PDF mesclado criado com sucesso!

# %%
from PyPDF2 import PdfMerger
from pathlib import Path

pdf1 = "Evolução_Amazon.pdf"
pdf2 = "SEBRAE-AMAZON.pdf"
pdf3 = "Mercado_Livre.pdf"

try:
    juntarPDFs = PdfMerger()

    for pdf in [pdf1, pdf2, pdf3]:
        juntarPDFs.append(pdf)    

    caminhoPasta = "PDF 3 Arquivos\\"
    Path(caminhoPasta).mkdir(parents=True,exist_ok=True)
    caminhoArquivoMesclado = Path(caminhoPasta + '3_arquivo_Juntos.pdf')

    with caminhoArquivoMesclado.open(mode='wb') as arquivoConcluido:
        juntarPDFs.write(arquivoConcluido)

    print("Arquivo PDF mesclado criado com sucesso!")

except FileNotFoundError:
    print(" Um dos arquivos PDF de origem não encontrado. Verifique o caminho dos arquivos")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# Arquivo PDF mesclado criado com sucesso!

# %%
from PyPDF2 import PdfReader
from pathlib import Path

caminhoArquivo = 'Mercado_Livre.pdf'

PDF_MercadoLivre = PdfReader(caminhoArquivo)

texto = """Entendendo sobre a criação do 
Preço
"""

numeroPagina = 1

for pagina in PDF_MercadoLivre.pages:
    textoDaPagina = pagina.extract_text()

    if texto in textoDaPagina:
        print("Texto está na página: ",numeroPagina)

    numeroPagina += 1

print("Pronto!")
# Out:
# Texto está na página:  25
# Pronto!

# %%
from PyPDF2 import PdfReader
from pathlib import Path

caminhoArquivo = 'Mercado_Livre.pdf'

PDF_MercadoLivre = PdfReader(caminhoArquivo)

texto = """Entendendo sobre a criação do 
Preço
"""

numeroPagina = 1

for pagina in PDF_MercadoLivre.pages:
    textoDaPagina = pagina.extract_text()

    if texto in textoDaPagina:
        print("Texto está na página: ", numeroPagina)
        textoDaPagina = textoDaPagina.replace(" .","\n")
        textoDaPagina = textoDaPagina.replace("\n \n","")
        textoDaPagina = textoDaPagina.replace(""" 
"""," ")
        textoDaPagina = textoDaPagina.replace("•Para","\n•Para")
        print(textoDaPagina)

    numeroPagina += 1

print("Pronto!")
# Out:
# Texto está na página:  25
# InternalOMercado Livre, possui algumas particularidades emque énecessário levar emconta antes dacriação dopreço deseuproduto
# Entendendo sobre a criação do Preço
#
# •Para ovendedor doMercado Livre, não existe inadimplência naplataforma, caso considere algum fator/percentual naformação depreço doseuproduto
# Lembre -sedeexcluí -lo,
# caso contrário omesmo estará duplicado
#
# •Desconsidere oinvestimento deMarketing dovalor total doproduto, este percentual está incluso nacomissão paga aoMercado Livre
# Lembre -sedeexcluí -lo,caso contrário o
# mesmo estará duplicado
#
# •Lembrem -setambém que acompra viaCartão deCrédito custo mínimo de3%dequando vendido àvista
# .NoMercado Livre não háesta despesa
#
# •Quando umproduto custa menos deR$120,0,énecessário considerar mais R$5,00porunidade aoconfigurar ofrete, produtos acima deR$120,00,considerar ovalor defrete no
# cálculo esempre oferecer grátis aocomprador
#
# ...

# %%
from PyPDF2 import PdfReader
from pathlib import Path

caminhoArquivo = 'Mercado_Livre.pdf'

PDF_MercadoLivre = PdfReader(caminhoArquivo)

texto = """Entendendo sobre a criação do 
Preço
"""

numeroPagina = 1

for pagina in PDF_MercadoLivre.pages:
    textoDaPagina = pagina.extract_text()

    if texto in textoDaPagina:
        print("Texto está na página: ", numeroPagina)

        textoDaPagina = textoDaPagina.replace(" .","/n").replace("\n \n","").replace(""" 
        """," ")

        posicaoInicial = textoDaPagina.find("LEMBRANDO QUE : ")
        posicaoFinal = textoDaPagina.find("links abaixo.",posicaoInicial + 1) + len("links abaixo.")

        if posicaoInicial != -1 and posicaoFinal != -1:
            textoSeparado = textoDaPagina[posicaoInicial:posicaoFinal]
            print(textoSeparado)
        else:
            print("Texto não encontrado na página.")

    numeroPagina += 1

print("Pronto!")
# Out:
# Texto está na página:  25
# LEMBRANDO QUE : os preços finais em amarelo ainda não condicionam o frete, valor este que será mostrado durante
# a criação do anúncio e/ou de acordo com a peça consultar a tabela de preços, disponível nos links abaixo.
# Pronto!

# %%
from PyPDF2 import PdfReader

pdf = PdfReader("ProfessoraRosiane.pdf")

urls = []

for pagina in range(len(pdf.pages)):
    paginaSelecionada = pdf.pages[pagina]

    try:
        for url in paginaSelecionada.get('/Annots',[]):
            texto = str(url)
            if ".com" in texto:
                urls.append(url.get('/A',{}).get('/URI',''))
                print(urls)

    except KeyError:
        pass

print("Pronto!")
# Out:
# ['https://www.google.com/']
# ['https://www.google.com/', 'https://www.google.com/']
# ['https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/']
# ['https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/']
# ['https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/']
# ['https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/', 'https://www.google.com/']
# Pronto!

# %%
from pikepdf import Pdf, PdfImage
from pathlib import Path

caminhoArquivo = "Evolução_Amazon.pdf"

arquivoPDF = Pdf.open(caminhoArquivo)

pastaImagens = Path("Imagens_PDF")

Path.mkdir(pastaImagens,exist_ok=True)

contador = 0

for i, pagina in enumerate(arquivoPDF.pages):
    for nome, imagem in pagina.images.items():
        imagemCapturada = PdfImage(imagem)

        caminhoImagem = pastaImagens / f"imagem_{contador}.jpg"

        imagemCapturada.extract_to(fileprefix=str(caminhoImagem))

        contador += 1

print("Imagens salvas com sucesso")
# Out:
# Imagens salvas com sucesso
