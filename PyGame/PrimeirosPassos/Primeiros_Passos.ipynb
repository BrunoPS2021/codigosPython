# %%
pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\users\bruno.pereira.silva\appdata\local\anaconda3\lib\site-packages (2.6.1)Note: you may need to restart the kernel to use updated packages.

# %%
import pygame

print(pygame.ver)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2.6.1

# %%
import pygame

pygame.init()

largura,altura = 800,600
janela = pygame.display.set_mode((largura,altura))
fonte = pygame.font.SysFont(None,74)
texto = fonte.render("Olá Mundo!",True,(255,255,255))
rodando = True

while rodando:
    for evento in pygame.event.get():
        if evento.type == pygame.QUIT:
            rodando = False

    janela.blit(texto,(250,259))
    pygame.display.update()

pygame.quit()

# %%
import pygame

pygame.init()

largura, altura = 500, 500

janela = pygame.display.set_mode((largura,altura))
vermelho = (255,0,0)
azul = (0,0,255)
rodando = True

while rodando:
    for evento in pygame.event.get():
        if evento.type == pygame.QUIT:
            rodando = False

    pygame.draw.rect(janela,vermelho,(50,50,100,50))
    pygame.draw.circle(janela,azul,(250,250),50)
    pygame.display.update()

pygame.quit()

# %%
import pygame

pygame.init()

tela_largura, tela_altura = 800, 600

janela = pygame.display.set_mode((tela_largura,tela_altura))
vermelho = (255,0,0)
azul = (0,0,255)
branco = (255,255,255)
verde = (0,255,0)
rodando = True

while rodando:
    for evento in pygame.event.get():
        if evento.type == pygame.QUIT:
            rodando = False

    janela.fill(branco)

    pygame.draw.rect(janela,vermelho,(50,50,100,50))
    pygame.draw.circle(janela,azul,(250,150),75)
    pygame.draw.line(janela,verde,(100,200),(300,350),5)
    pygame.display.update()

pygame.quit()

# %%
import pygame

pygame.init()

largura_tela = 800
altura_tela = 600

tela = pygame.display.set_mode((largura_tela,altura_tela))

caminho_imagem = 'imagem_exemplo.jpg'
imagem_original = pygame.image.load(caminho_imagem)

tamanho_novo = (700,500)

imagem_redimensionada = pygame.transform.scale(imagem_original,tamanho_novo)

execute = True

while execute:
    for evento in pygame.event.get():
        if evento.type == pygame.QUIT:
            execute = False
    
    tela.fill((0,0,0))
    tela.blit(imagem_redimensionada,(50,50))

    pygame.display.flip()

pygame.quit()

# %%
import pygame

pygame.init()

largura_tela,altura_tela = 800,600
tela = pygame.display.set_mode((largura_tela,altura_tela))

preto = (0,0,0)
tamanho_quadro = (64,64)

caminho_imagem_1 = 'Passaro1.png'
caminho_imagem_2 = 'Passaro2.png'

quadro_1 = pygame.transform.scale(pygame.image.load(caminho_imagem_1),tamanho_quadro)
quadro_2 = pygame.transform.scale(pygame.image.load(caminho_imagem_2),tamanho_quadro)
quadros = [quadro_1,quadro_2]

indice_quadro_atual = 0

tempo_mudanca_quadro = 500

ultimo_mudanca = pygame.time.get_ticks()

sprite_posicao = [100,300]

sprite_velocidade = [2,0]
executando = True

while executando:
    for evento in pygame.event.get():
        if evento.type == pygame.QUIT:
            executando = False

    sprite_posicao[0] += sprite_velocidade[0]

    if sprite_posicao[0] <= 0 or sprite_posicao[0] + tamanho_quadro[0] >= largura_tela:
        sprite_velocidade[0] *= -1
    
    tempo_atual = pygame.time.get_ticks()

    if tempo_atual - ultimo_mudanca > tempo_mudanca_quadro:
        indice_quadro_atual = (indice_quadro_atual + 1) % len(quadros)
        ultimo_mudanca = tempo_atual
    
    tela.fill(preto)
    tela.blit(quadros[indice_quadro_atual],sprite_posicao)

    pygame.display.flip()
    pygame.time.Clock().tick(60)    

pygame.quit()

# %%
import pygame
import random

pygame.init()

largura_tela, altura_tela = 800,600
tela = pygame.display.set_mode((largura_tela, altura_tela))

preto = (0,0,0)
branco = (255,255,255)

x,y = largura_tela // 2, altura_tela // 2
largura_retangulo, altura_retangulo = 50,50
velocidade = 5

cor_retangulo = branco

executando = True

while executando:
    for evento in pygame.event.get():
        if evento.type == pygame.QUIT:
            executando = False

        if evento.type == pygame.KEYDOWN:
            if evento.key == pygame.K_ESCAPE:
                executando = False
        
        if evento.type == pygame.MOUSEBUTTONDOWN:
            if evento.button == 1:# 1 => botão esquerdo
                cor_retangulo = (random.randint(0,255),random.randint(0,255),random.randint(0,255))
        
        teclas_pressionadas = pygame.key.get_pressed()
        if teclas_pressionadas[pygame.K_w]:
            y -= velocidade

        if teclas_pressionadas[pygame.K_s]:
            y += velocidade

        if teclas_pressionadas[pygame.K_a]:
            x -= velocidade
        
        if teclas_pressionadas[pygame.K_d]:
            x += velocidade

        x = max(0,min(x,largura_tela - largura_retangulo))
        y = max(0,min(y,altura_tela-altura_retangulo))
        tela.fill(preto)
        
        pygame.draw.rect(tela,cor_retangulo,(x,y,largura_retangulo,altura_retangulo))
        pygame.display.flip()
        pygame.time.Clock().tick(60)        
    
pygame.quit()
